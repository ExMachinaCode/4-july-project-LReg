# %% [markdown]
# <a href="https://colab.research.google.com/github/ExMachinaCode/4-july-project-LReg/blob/main/redEye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader. download("red eyes of people",limit=1000,output_dir='images')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# [!!]Indexing page: 1281
#
# [%] Indexed 18 Images on Page 1281.
#
# ...
#
#
#
# [!!]Indexing page: 1282
#
# [%] Indexed 18 Images on Page 1282.
#
# ...
#
#
#
# [!!]Indexing page: 1283
#
# [%] Indexed 24 Images on Page 1283.
#
# ...
#
#
#
# [!!]Indexing page: 1284
#
# [%] Indexed 24 Images on Page 1284.
#
# ...
#
#
#
# [!!]Indexing page: 1285
#
# [%] Indexed 24 Images on Page 1285.
#
# ...
#
#
#
# [!!]Indexing page: 1286
#
# [%] Indexed 18 Images on Page 1286.
#
# ...
#
#
#
# [!!]Indexing page: 1287
#
# [%] Indexed 18 Images on Page 1287.
#
# ...
#
#
#
# [!!]Indexing page: 1288
#
# [%] Indexed 18 Images on Page 1288.
#
# ...
#
#
#
# [!!]Indexing page: 1289
#
# [%] Indexed 18 Images on Page 1289.
#
# ...
#
#
#
# [!!]Indexing page: 1290
#
# [%] Indexed 18 Images on Page 1290.
#
# ...
#
#
#
# [!!]Indexing page: 1291
#
# [%] Indexed 24 Images on Page 1291.
#
# ...
#
#
#
# [!!]Indexing page: 1292
#
# [%] Indexed 18 Images on Page 1292.
#
# ...
#
#
#
# [!!]Indexing page: 1293
#
# ...
